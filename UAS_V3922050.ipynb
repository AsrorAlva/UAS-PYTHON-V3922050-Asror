# %%
from bs4 import BeautifulSoup as bs
import requests as req
import glob
import json
import os
import csv
import time

# Base URL and API URL for Bukalapak
baseurl = 'https://www.bukalapak.com/u/'
apiurl = 'https://api.bukalapak.com/stores/'

class Bukalapak:
    def __init__(self, username):
        self.username = username
        self.urltoko = baseurl + username
        self.headerbrowser = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:74.0) Gecko/20100101 Firefox/74.0'}

        # Send a GET request to the seller's page
        pg_data = req.get(self.urltoko, headers=self.headerbrowser, timeout=3000)
        try:
            if pg_data.status_code == 200:
                soup = bs(pg_data.text, 'html.parser')

                # Get the seller's ID
                print("[+] Mengambil id penjual ...")
                self.idseller = soup.find('a', attrs={'data-user-id': True})['data-user-id']
                print("[+] Id penjual: " + self.idseller)

                # Get the access token for the API
                print("[+] Mengambil access token ...")
                stoken = soup.find_all('script')
                gtoken = str(stoken[4]).replace("<script>localStorage.setItem('bl_token', '", "").replace(
                    "');</script>", "")
                gtoken = json.loads(gtoken)
                self.token = gtoken['access_token']
                print("[+] Access token: " + self.token)

                # Start grabbing the products
                self.grabproduk()
            else:
                print("[!] Username tidak ditemukan!")
        except Exception as e:
            print(e)
            print("[!] Website down!")
            exit()

    def grabproduk(self):
        print("=== GRABBING PRODUK ===")
        print("[+] Memulai download halaman produk ...")
        print("\x1B[3m" + "(delay 3 detik untuk menghindari anti-spam!)" + "\x1B[0m")

        # Get the total number of products from the API
        api = apiurl + str(self.idseller) + '/products?offset=0&limit=50&access_token=' + self.token
        total_product = req.get(api, headers=self.headerbrowser, timeout=3000).json()
        total = total_product['meta']['total']
        print("[+] Total produk: " + str(total))

        # Remove old files
        print("[+] Hapus file lama ...")
        if not os.path.exists("data"):
            os.makedirs("data")
        for filename in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            os.remove(filename)
        for filename in glob.glob(str(self.idseller) + "_bukalapak.csv"):
            os.remove(filename)

        # Grab each page of products
        a = 0
        b = 0
        while a < total and b < 1:
            print("-> download halaman ke-" + str(b + 1))
            api = apiurl + str(self.idseller) + '/products?offset=' + str(a) + '&limit=50&access_token=' + self.token
            pg_data = req.get(api, headers=self.headerbrowser, timeout=3000).json()

            # If there are no more products, break the loop
            if not pg_data['data']:
                break

            # Save the product data to a JSON file
            with open("data/" + str(self.idseller) + "_bukalapak" + str(b) + ".json", 'w') as json_file:
                json.dump(pg_data['data'], json_file)

            # Increment offsets and wait for 3 seconds to avoid anti-spam measures
            a += 50
            b += 1
            time.sleep(3)

        # Merge all JSON files into one
        print("[+] Merging data produk ...")
        data = []
        for f in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            with open(f) as infile:
                data.extend(json.load(infile))
        with open("data/" + str(self.idseller) + "_bukalapak_all.json", 'w') as outfile:
            json.dump(data, outfile)

        # Create a CSV file with the product data
        print("[+] Membuat csv data produk ...")
        f_data = []
        for i in data:
            f_data.append([
    i['name'],
    i['price'],
    i['category']['name'],
    i.get('city', 'N/A')
])



        f_header = ['nama_produk', 'harga', 'kategori', 'kota']

        with open(str(self.idseller) + '_bukalapak.csv', 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(f_header)
            writer.writerows(f_data)

        print('selesai! ' + str(self.idseller) + '_bukalapak.csv')


sname = input("[+] Masukkan username seller: https://www.bukalapak.com/u/")
act = Bukalapak(sname)
# Out:
# [+] Masukkan username seller: https://www.bukalapak.com/u/anggrek_store716
# [+] Mengambil id penjual ...
# [+] Id penjual: 202175296
# [+] Mengambil access token ...
# [+] Access token: eyJhbGciOiJSUzI1NiIsImtpZCI6ImFjY291bnRzLmp3dC5hY2Nlc3MtdG9rZW4iLCJ0eXAiOiJKV1QifQ.....eQOn7MWE-fOS5Sw0oCFr-6HRRZJ2pGrnr9PN6bYi_uleC8cBhd9n2Amzu8qqS1GPw4fYR7kEiT4YhA9YO_3aTNTdQBqUpNPXDaWQK0GW3z0CQgk7yDhOCrRKOSUb_Bo_iIxAtxNs6wSj06vmxuqVeCCztrwCmcZQL0fAnPCXO6FnXk2Xe5gShP4h2XXTJ9YMIj7II0yRhpRPvMzzaymqprurVKr_OwiHNn3EgkRTxIuda_tMHxTFM_buUhdNn7jC6A8NdcXedcEFpgFFnSSDdGFmIVYTCUHR_YcdBeVkA-q4mkCbZmuaUgTOdH5lgqxMka7uYSBNppELxojOIjHK0w
# === GRABBING PRODUK ===
# [+] Memulai download halaman produk ...
# (delay 3 detik untuk menghindari anti-spam!)
# [+] Total produk: 411
# [+] Hapus file lama ...
# -> download halaman ke-1
# [+] Merging data produk ...
# [+] Membuat csv data produk ...
# selesai! 202175296_bukalapak.csv

# %%
import pandas as pd

# reading the database
data = pd.read_csv("202175296_bukalapak.csv")

# printing the top 52 rows
display(data.head(52))
# Out:
#                                           nama_produk    harga  \
# 0   OLIKE GH1 HEADPHONE GAMING WIRED MICROPHONE HE...   139000
# 1   VIVAN Liberty T110 FF True Wireless Bluetooth ...   295000
# 2   BONBOX TBTW30201 empat Makan Lunch Box Kotak B...    50000
# 3   BONBOX BCT811 Cleaning Tools Keranjang Lipat S...   103000
# 4   BONBOX BSB3202 Storage Box Serbaguna Kotak Pen...    37000
# 5   Samono SW-HU250 5.2L Air Humidifier Mesin Pele...   375000
# 6   SAMONO BBS3305 Rak Kamar Mandi Sudut Bulat Kua...    19000
# 7   Samono 750ML SW-CMB06B Coffee Maker Mesin Kopi...   178000
# 8   SAMONO SW-ES02 Shaver Alat Cukur Jenggot Listr...   135000
# 9   BONBOX BCH21202 Gantungan Baju Isi 5pcs Gantun...    27000
# 10  SAMONO SW-C200 Chopper Magic Duck Penghalus Ma...   184000
# 11  Charger Original VIVAN Fast Charging 35W Gan P...   164000
# 12  VIVAN  VDCL120 / VDCC120 Kabel Type C to Light...    59000
# 13  BONBOX BNP3201 Neck Pillow Bantal leher Gambar...    68000
# 14  OLIKE CF1 COOLING PAD GAMING FAN PHONE COOLER ...   137000
# 15  BONBOX BTW21201 Kotak Bekal 4 Grid Lunch Box K...    41000
# 16  BONBOX BTW21203 Kotak Makan 2 Layer 6 Grid Lun...    46000
# 17  OLIKE KEPALA CHARGER 33W IPHONE TYPE C PD ADAP...   119000
# 18  BONBOX BCH30201 Gantungan Jemuran Gantung Puta...    31000
# 19  OLIKE KABEL CHARGE DATA 3IN1 66W FAST CHARGING...   100000
# 20  OLIKE MIC KARAOKE BLUETOOTH MICROPHONE WIRELES...   151000
# 21  OLIKE SPEAKER BLUETOOTH PORTABLE STEREO TWS WI...   202000
# 22  OLIKE E15 HEADSET HANDSFREE 3.5MM WIRED EARPHO...    20500
# 23  Gamen Portable Desk GPD100 Black Meja Laptop L...    93000
# 24  BONBOX BMB3202 Tas Make Up Pouch Make Up Organ...    18000
# 25  OLIKE S3H SPEAKER BLUETOOTH WIRELESS PORTABLE ...   183000
# 26  BONBOX BMT30201 30x30cm Isi 9 pcs Playmat Matr...    60000
# 27  OLIKE C202 Charger Kepala Charger Fast Chargin...    20000
# 28  BONBOX BMB10 Tas Penyimpanan Travel Bag Multif...    38000
# 29  Headset Robot REC240S Headset Wired Earphone B...    46000
# 30  Olike OBS-600 Wireless Portable Speaker Blueto...    85000
# 31  ROBOT Optical Mouse Office Wired M100 / Mini M...    24000
# 32  BONBOX BTW70 Lunch Box / Kotak bekal makan sia...    47000
# 33  BONBOX BTW60 Piring Makan Set Anak 6 in 1 BPA ...    45000
# 34  Samono SW-BS01 Timbangan Badan Digital LED Bod...   148000
# 35            SET TOP BOX MATRIX HD DVB T2 TV DIGITAL   270000
# 36  Charger VIVAN Fast Charging GAN02S 65W Portabl...   265000
# 37  VIVAN Kabel Converter Type C to Jack AUX 3.5mm...    52000
# 38  Headset Robot RE40 Headset Wired Earphone Full...    20000
# 39  ACOME ALP03 Lampu Smart Multicolor 16 Juta War...   139000
# 40  Olike C304 Kepala Charger Quick Charge Origina...    40000
# 41  GAMEN Gaming Fancooler Radiator Coolingfan Sma...   160000
# 42  Olike CP1 Card Holder Dompet Kartu Tempelan HP...    23000
# 43  Olike SL1 Wireless Portable Beatz Speaker Type...    69000
# 44  HEADSET Wired ROBOT RE602 Powerful Bass High D...    25000
# 45  OLIKE EJ2 TRUE WIRELESS BLUETOOTH EARPHONE EAR...   123000
# 46  VIVAN Kabel Data 3 in 1 Fast Charging 3.5A Mic...    73000
# 47  Samono 300W SW-C300 Food Chopper Kaca Blender ...    55000
# 48  Acome APF01 Smart Pet Feeder Dispenser Makanan...  1218000
# 49  BONBOX Dispenser Beras Rice Box Kapasitas 10KG...   157000
#
#                            kategori  kota
# 0                         Headphone   NaN
# 1                Headset (Earphone)   NaN
# 2       Penyimpanan & Kotak Makanan   NaN
# 3                    Ember & Baskom   NaN
# 4    Tempat Penyimpanan & Organizer   NaN
# 5                Elektronik Lainnya   NaN
# 6    Tempat Penyimpanan & Organizer   NaN
# 7                      Coffee Maker   NaN
# 8                   Peralatan Cukur   NaN
# 9                    Gantungan Baju   NaN
# 10                          Blender   NaN
# 11                          Charger   NaN
# 12                       Kabel Data   NaN
# 13                  Bantal & Guling   NaN
# 14                       Cooler Fan   NaN
# 15      Penyimpanan & Kotak Makanan   NaN
# 16      Penyimpanan & Kotak Makanan   NaN
# 17                          Charger   NaN
# 18                Furniture Lainnya   NaN
# 19                       Kabel Data   NaN
# 20                          Speaker   NaN
# 21                          Speaker   NaN
# 22               Headset (Earphone)   NaN
# 23                             Meja   NaN
# 24                       Pouch Bags   NaN
# 25                          Speaker   NaN
# 26                           Puzzle   NaN
# 27                          Charger   NaN
# 28                    Travel Pouch    NaN
# 29               Headset (Earphone)   NaN
# 30                          Speaker   NaN
# 31                            Mouse   NaN
# 32   Tempat Penyimpanan & Organizer   NaN
# 33               Perlengkapan Makan   NaN
# 34  Timbangan & Alat Ukur Kesehatan   NaN
# 35       Media Player & Set Top Box   NaN
# 36                          Charger   NaN
# 37                Aksesoris Lainnya   NaN
# 38               Headset (Earphone)   NaN
# 39          Lampu & Alat Penerangan   NaN
# 40                          Charger   NaN
# 41                       Cooler Fan   NaN
# 42                Aksesoris Lainnya   NaN
# 43                          Speaker   NaN
# 44               Headset (Earphone)   NaN
# 45               Headset (Earphone)   NaN
# 46                       Kabel Data   NaN
# 47                          Blender   NaN
# 48                    Pet Aksesoris   NaN
# 49      Penyimpanan & Kotak Makanan   NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("202175296_bukalapak.csv")

# Selecting the first 50 data points
data_subset = data.head(52)

# Scatter plot with 'rating' against 'jumlah_rating'
plt.scatter(data_subset['harga'], data_subset['kategori'])

# Adding title to the plot
plt.title("Elektronik - Scatter Plot")

# Setting the x and y labels
plt.xlabel('harga')
plt.ylabel('kategori')

# Save the plot as a PNG file
plt.savefig('scatter_plot.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import pandas as pd # Digunakan untuk mengimpor modul Pandas ke dalam script.
import matplotlib.pyplot as plt # Digunakan untuk mengimpor modul Matplotlib ke dalam script.

# Digunakan untuk membaca file CSV dengan nama "data_aksesoris.csv".
data = pd.read_csv("202175296_bukalapak.csv")

# Digunakan untuk membuat sebuah figur baru dalam visualisasi dengan ukuran 12x7 inci.
plt.figure(figsize=(12, 7))

# Menghitung jumlah kemunculan tiap nilai dalam kolom 'Address'.
plt.hist(data['harga'])

# Menambahkan judul.
plt.title("Histogram Aksesoris Elektronik")

# Menyimpan Histogram dalam format JPG dengan nama file 'Histogram_Aksesoris.jpg'.
plt.savefig('Histogram_Aksesoris.jpg', dpi=300, bbox_inches='tight')

# Menampilkan hasil Histogram.
plt.show()

# %%
import pandas as pd # Digunakan untuk mengimpor modul Pandas ke dalam script.
import matplotlib.pyplot as plt # Digunakan untuk mengimpor modul Matplotlib ke dalam script.

# Digunakan untuk membaca file CSV dengan nama "data_aksesoris.csv".
data = pd.read_csv("202175296_bukalapak.csv")

# Digunakan untuk membuat sebuah figur baru dalam visualisasi dengan ukuran 12x7 inci.
plt.figure(figsize=(12, 7))

data['harga'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)  # Membuat pie chart dengan persen.
plt.ylabel('') # Menghapus label sumbu Y.

# Menambahkan judul.
plt.title("Pie Chart Aksesoris Elektronik")

# Menyimpan Pie Chart dalam format JPG dengan nama file 'PieChart_Aksesoris.jpg'.
plt.savefig('PieChart_Aksesoris1.jpg', dpi=300, bbox_inches='tight')

# Menampilkan hasil Pie Chart.
plt.show()
